# %%
# Import Dependencies
import numpy as np
import pandas as pd

# Import citipy
from citipy import citipy

# %%
# Create random lat and long combo's
lats = np.random.uniform(-90.00, 90.00, size = 2000)
long = np.random.uniform(-180.00, 180.00, size = 2000)
lats_long = zip(lats, long)
lats_long

# %%
# Add the lats and long's to a list
coordinates = list(lats_long)

# %%
# Empty list for holding rndm cities
cities = []

# Find the nearest city to the Lat and Long, if unique add to list
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
# Check how many cities were returned
len(cities)
# Out:
# 779

# %%
# Import requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Variable for weather API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Empty list for weather data
city_data = []

# Print the retrieval log
print("Beginning of Retrieval Log")
print("--------------------------")

# Counters
record_count = 1
set_count = 1

# Loop through the cities
for i, city in enumerate(cities):
    # Group in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record = 1
    
    # Endpoint URL
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers and city
    print(f"Processing record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    # API request through Try and Except
    try:
        # Parse the JSON
        city_weather = requests.get(city_url).json()
        # Parse needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # City date conversion
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind": city_wind,
                          "Weather Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})
        
    except:
        print("City not found. Skipping...")
        pass

# Data retrieval complete
print("--------------------------")
print("Data Retrieval Complete   ")
# Out:
# Beginning of Retrieval Log
# --------------------------
# Processing record 1 of Set 1 | dikson
# Processing record 2 of Set 1 | mount gambier
# Processing record 3 of Set 1 | iralaya
# Processing record 4 of Set 1 | hilo
# Processing record 5 of Set 1 | punta arenas
# Processing record 6 of Set 1 | mataura
# Processing record 7 of Set 1 | avarua
# Processing record 8 of Set 1 | castro
# Processing record 9 of Set 1 | east london
# Processing record 10 of Set 1 | isla vista
# Processing record 11 of Set 1 | iqaluit
# Processing record 12 of Set 1 | keti bandar
# Processing record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing record 14 of Set 1 | rosarito
# Processing record 15 of Set 1 | charagua
# Processing record 16 of Set 1 | hamilton
# Processing record 17 of Set 1 | buala
# Processing record 18 of Set 1 | faya
# Processing record 19 of Set 1 | bethel
# Processing record 20 of Set 1 | lannion
# Processing record 21 of Set 1 | ponta do sol
# Processing record 22 of Set 1 | muborak
# Processing record 23 of Set 1 | port alfred
# Processing record 24 of Set 1 | ahipara
# Processing record 25 of Set 1 | kununurra
# Processing record 26 of Set 1 | norman wells
# Processing record 27 of Set 1 | provideniya
# Processing record 28 of Set 1 | cabinda
# Processing record 29 of Set 1 | bluff
# Processing record 30 of Set 1 | albany
# Processing record 31 of Set 1 | uttaradit
# Processing record 32 of Set 1 | sinop
# Processing record 33 of Set 1 | saskylakh
# Processing record 34 of Set 1 | mergui
# City not found. Skipping...
# Processing record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing record 36 of Set 1 | severo-kurilsk
# Processing record 37 of Set 1 | esperance
# Processing record 38 of Set 1 | guaiba
# Processing record 39 of Set 1 | rikitea
# Processing record 40 of Set 1 | ushuaia
# Processing record 41 of Set 1 | san quintin
# Processing record 42 of Set 1 | yeppoon
# Processing record 43 of Set 1 | kodiak
# Processing record 44 of Set 1 | bilibino
# Processing record 45 of Set 1 | ribeira grande
# Processing record 46 of Set 1 | mulchen
# Processing record 47 of Set 1 | atuona
# Processing record 48 of Set 1 | port elizabeth
# Processing record 49 of Set 1 | aksarka
# Processing record 50 of Set 1 | saldanha
# Processing record 51 of Set 2 | bambous virieux
# Processing record 52 of Set 2 | husavik
# Processing record 53 of Set 2 | verkhnyaya maksakovka
# Processing record 54 of Set 2 | fethiye
# Processing record 55 of Set 2 | altayskoye
# Processing record 56 of Set 2 | itarema
# Processing record 57 of Set 2 | pokhara
# Processing record 58 of Set 2 | vaini
# Processing record 59 of Set 2 | jamestown
# Processing record 60 of Set 2 | hualmay
# Processing record 61 of Set 2 | lanzhou
# Processing record 62 of Set 2 | urdzhar
# City not found. Skipping...
# Processing record 63 of Set 2 | zyryanka
# Processing record 64 of Set 2 | avera
# Processing record 65 of Set 2 | busselton
# Processing record 66 of Set 2 | atar
# Processing record 67 of Set 2 | chokurdakh
# Processing record 68 of Set 2 | cape town
# Processing record 69 of Set 2 | novoleushkovskaya
# Processing record 70 of Set 2 | angra dos reis
# Processing record 71 of Set 2 | alihe
# Processing record 72 of Set 2 | kaputa
# Processing record 73 of Set 2 | sur
# Processing record 74 of Set 2 | nguiu
# City not found. Skipping...
# Processing record 75 of Set 2 | thompson
# Processing record 76 of Set 2 | hermanus
# Processing record 77 of Set 2 | moron
# Processing record 78 of Set 2 | udomlya
# Processing record 79 of Set 2 | aklavik
# Processing record 80 of Set 2 | vila
# Processing record 81 of Set 2 | angoche
# Processing record 82 of Set 2 | jujuy
# City not found. Skipping...
# Processing record 83 of Set 2 | coihaique
# Processing record 84 of Set 2 | kahului
# Processing record 85 of Set 2 | marsh harbour
# Processing record 86 of Set 2 | beringovskiy
# Processing record 87 of Set 2 | haines junction
# Processing record 88 of Set 2 | grand gaube
# Processing record 89 of Set 2 | sol-iletsk
# Processing record 90 of Set 2 | labuhan
# Processing record 91 of Set 2 | ambilobe
# Processing record 92 of Set 2 | pangnirtung
# Processing record 93 of Set 2 | sao joao da barra
# Processing record 94 of Set 2 | amderma
# City not found. Skipping...
# Processing record 95 of Set 2 | kaitangata
# Processing record 96 of Set 2 | portland
# Processing record 97 of Set 2 | hithadhoo
# Processing record 98 of Set 2 | belushya guba
# City not found. Skipping...
# Processing record 99 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing record 100 of Set 2 | qaanaaq
# Processing record 101 of Set 3 | suntar
# Processing record 102 of Set 3 | hobart
# Processing record 103 of Set 3 | madera
# Processing record 104 of Set 3 | kavaratti
# Processing record 105 of Set 3 | georgetown
# Processing record 106 of Set 3 | yellowknife
# Processing record 107 of Set 3 | pevek
# Processing record 108 of Set 3 | auki
# Processing record 109 of Set 3 | archidona
# Processing record 110 of Set 3 | kutoarjo
# Processing record 111 of Set 3 | maniitsoq
# Processing record 112 of Set 3 | geraldton
# Processing record 113 of Set 3 | baruun-urt
# Processing record 114 of Set 3 | saint-joseph
# Processing record 115 of Set 3 | huarmey
# Processing record 116 of Set 3 | chirala
# Processing record 117 of Set 3 | meyungs
# City not found. Skipping...
# Processing record 118 of Set 3 | khandyga
# Processing record 119 of Set 3 | tsihombe
# City not found. Skipping...
# Processing record 120 of Set 3 | new norfolk
# Processing record 121 of Set 3 | bengkulu
# Processing record 122 of Set 3 | palmer
# Processing record 123 of Set 3 | shieli
# Processing record 124 of Set 3 | taldan
# Processing record 125 of Set 3 | kismayo
# Processing record 126 of Set 3 | puerto ayora
# Processing record 127 of Set 3 | leopold
# Processing record 128 of Set 3 | hammerfest
# Processing record 129 of Set 3 | kapaa
# Processing record 130 of Set 3 | anniston
# Processing record 131 of Set 3 | bredasdorp
# Processing record 132 of Set 3 | boundiali
# Processing record 133 of Set 3 | kenora
# Processing record 134 of Set 3 | lavrentiya
# Processing record 135 of Set 3 | tuatapere
# Processing record 136 of Set 3 | cockburn town
# Processing record 137 of Set 3 | harwich
# Processing record 138 of Set 3 | aflu
# City not found. Skipping...
# Processing record 139 of Set 3 | tatarskaya kargala
# Processing record 140 of Set 3 | lagoa
# Processing record 141 of Set 3 | egvekinot
# Processing record 142 of Set 3 | abbeville
# Processing record 143 of Set 3 | san patricio
# Processing record 144 of Set 3 | vestmanna
# Processing record 145 of Set 3 | malatya
# Processing record 146 of Set 3 | tiksi
# Processing record 147 of Set 3 | pekan
# Processing record 148 of Set 3 | saraiu
# Processing record 149 of Set 3 | camacha
# Processing record 150 of Set 3 | ayorou
# Processing record 151 of Set 4 | souillac
# Processing record 152 of Set 4 | roald
# Processing record 153 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing record 154 of Set 4 | manokwari
# Processing record 155 of Set 4 | mar del plata
# Processing record 156 of Set 4 | rocha
# Processing record 157 of Set 4 | katsuura
# Processing record 158 of Set 4 | amazar
# Processing record 159 of Set 4 | burley
# Processing record 160 of Set 4 | ancud
# Processing record 161 of Set 4 | kruisfontein
# Processing record 162 of Set 4 | ostrovnoy
# Processing record 163 of Set 4 | mayskiy
# Processing record 164 of Set 4 | sovetskiy
# Processing record 165 of Set 4 | saint george
# Processing record 166 of Set 4 | half moon bay
# Processing record 167 of Set 4 | conde
# Processing record 168 of Set 4 | visby
# Processing record 169 of Set 4 | codrington
# Processing record 170 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing record 171 of Set 4 | nikolskoye
# Processing record 172 of Set 4 | alice springs
# Processing record 173 of Set 4 | kalianget
# Processing record 174 of Set 4 | astoria
# Processing record 175 of Set 4 | tumannyy
# City not found. Skipping...
# Processing record 176 of Set 4 | burnie
# Processing record 177 of Set 4 | sokol
# Processing record 178 of Set 4 | grand river south east
# City not found. Skipping...
# Processing record 179 of Set 4 | port hedland
# Processing record 180 of Set 4 | chor
# Processing record 181 of Set 4 | victoria
# Processing record 182 of Set 4 | mitsamiouli
# Processing record 183 of Set 4 | srednekolymsk
# Processing record 184 of Set 4 | qafsah
# City not found. Skipping...
# Processing record 185 of Set 4 | alexandria
# Processing record 186 of Set 4 | shimoda
# Processing record 187 of Set 4 | paradwip
# City not found. Skipping...
# Processing record 188 of Set 4 | tagusao
# Processing record 189 of Set 4 | flinders
# Processing record 190 of Set 4 | urucara
# Processing record 191 of Set 4 | ushtobe
# Processing record 192 of Set 4 | butaritari
# Processing record 193 of Set 4 | nome
# Processing record 194 of Set 4 | bathsheba
# Processing record 195 of Set 4 | porto novo
# Processing record 196 of Set 4 | metro
# Processing record 197 of Set 4 | waingapu
# Processing record 198 of Set 4 | lompoc
# Processing record 199 of Set 4 | clyde river
# Processing record 200 of Set 4 | te anau
# Processing record 201 of Set 5 | azangaro
# Processing record 202 of Set 5 | tautira
# Processing record 203 of Set 5 | san cristobal
# Processing record 204 of Set 5 | angoram
# Processing record 205 of Set 5 | upernavik
# Processing record 206 of Set 5 | arraial do cabo
# Processing record 207 of Set 5 | alghero
# Processing record 208 of Set 5 | zhuanghe
# Processing record 209 of Set 5 | vaitupu
# City not found. Skipping...
# Processing record 210 of Set 5 | barrow
# Processing record 211 of Set 5 | surt
# Processing record 212 of Set 5 | mana
# Processing record 213 of Set 5 | santa fe
# Processing record 214 of Set 5 | karoi
# Processing record 215 of Set 5 | dillon
# Processing record 216 of Set 5 | ilulissat
# Processing record 217 of Set 5 | palu
# Processing record 218 of Set 5 | warqla
# City not found. Skipping...
# Processing record 219 of Set 5 | skalistyy
# City not found. Skipping...
# Processing record 220 of Set 5 | olinda
# Processing record 221 of Set 5 | ayan
# Processing record 222 of Set 5 | jiddah
# City not found. Skipping...
# Processing record 223 of Set 5 | tyukhtet
# Processing record 224 of Set 5 | coahuayana
# Processing record 225 of Set 5 | beibei
# Processing record 226 of Set 5 | straumen
# Processing record 227 of Set 5 | kasongo-lunda
# Processing record 228 of Set 5 | majene
# Processing record 229 of Set 5 | samusu
# City not found. Skipping...
# Processing record 230 of Set 5 | sorong
# Processing record 231 of Set 5 | margate
# Processing record 232 of Set 5 | mahon
# Processing record 233 of Set 5 | fairbanks
# Processing record 234 of Set 5 | inirida
# Processing record 235 of Set 5 | cradock
# Processing record 236 of Set 5 | ngukurr
# City not found. Skipping...
# Processing record 237 of Set 5 | christiana
# Processing record 238 of Set 5 | korla
# Processing record 239 of Set 5 | coquimbo
# Processing record 240 of Set 5 | coulihaut
# City not found. Skipping...
# Processing record 241 of Set 5 | galiwinku
# City not found. Skipping...
# Processing record 242 of Set 5 | cidreira
# Processing record 243 of Set 5 | severo-yeniseyskiy
# Processing record 244 of Set 5 | biak
# Processing record 245 of Set 5 | safaga
# Processing record 246 of Set 5 | evensk
# Processing record 247 of Set 5 | zhongshu
# Processing record 248 of Set 5 | nouadhibou
# Processing record 249 of Set 5 | meulaboh
# Processing record 250 of Set 5 | khonuu
# City not found. Skipping...
# Processing record 251 of Set 6 | fort nelson
# Processing record 252 of Set 6 | nijar
# Processing record 253 of Set 6 | vardo
# Processing record 254 of Set 6 | nelson
# Processing record 255 of Set 6 | faanui
# Processing record 256 of Set 6 | shumikha
# Processing record 257 of Set 6 | bacolod
# Processing record 258 of Set 6 | guerrero negro
# Processing record 259 of Set 6 | laguna
# Processing record 260 of Set 6 | naranjal
# Processing record 261 of Set 6 | la palma
# Processing record 262 of Set 6 | saint-philippe
# Processing record 263 of Set 6 | cherskiy
# Processing record 264 of Set 6 | adrar
# Processing record 265 of Set 6 | prichard
# Processing record 266 of Set 6 | mokhsogollokh
# Processing record 267 of Set 6 | pumiao
# Processing record 268 of Set 6 | champerico
# Processing record 269 of Set 6 | monte alegre
# Processing record 270 of Set 6 | ponferrada
# Processing record 271 of Set 6 | hasaki
# Processing record 272 of Set 6 | leatherhead
# Processing record 273 of Set 6 | sao lourenco do sul
# Processing record 274 of Set 6 | baykalsk
# Processing record 275 of Set 6 | guanica
# Processing record 276 of Set 6 | teguldet
# Processing record 277 of Set 6 | kaspiysk
# Processing record 278 of Set 6 | morfovounion
# City not found. Skipping...
# Processing record 279 of Set 6 | kaka
# Processing record 280 of Set 6 | fortuna
# Processing record 281 of Set 6 | zapolyarnyy
# Processing record 282 of Set 6 | saryshagan
# City not found. Skipping...
# Processing record 283 of Set 6 | okhotsk
# Processing record 284 of Set 6 | florencia
# Processing record 285 of Set 6 | dundee
# Processing record 286 of Set 6 | two rivers
# Processing record 287 of Set 6 | alcacer do sal
# Processing record 288 of Set 6 | beaupre
# Processing record 289 of Set 6 | viedma
# Processing record 290 of Set 6 | torbay
# Processing record 291 of Set 6 | manta
# Processing record 292 of Set 6 | turukhansk
# Processing record 293 of Set 6 | gorom-gorom
# Processing record 294 of Set 6 | bull savanna
# Processing record 295 of Set 6 | burdur
# Processing record 296 of Set 6 | mragowo
# Processing record 297 of Set 6 | khatanga
# Processing record 298 of Set 6 | vestmannaeyjar
# Processing record 299 of Set 6 | tamiahua
# Processing record 300 of Set 6 | naze
# Processing record 301 of Set 7 | asau
# Processing record 302 of Set 7 | nantucket
# Processing record 303 of Set 7 | caraz
# Processing record 304 of Set 7 | salalah
# Processing record 305 of Set 7 | kiunga
# Processing record 306 of Set 7 | kita
# Processing record 307 of Set 7 | bolshoye nagatkino
# Processing record 308 of Set 7 | carnarvon
# Processing record 309 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing record 310 of Set 7 | vanimo
# Processing record 311 of Set 7 | smithers
# Processing record 312 of Set 7 | myanaung
# Processing record 313 of Set 7 | larnaca
# Processing record 314 of Set 7 | inta
# Processing record 315 of Set 7 | bibiani
# Processing record 316 of Set 7 | kavieng
# Processing record 317 of Set 7 | malabo
# Processing record 318 of Set 7 | hammelburg
# Processing record 319 of Set 7 | road town
# Processing record 320 of Set 7 | mahebourg
# Processing record 321 of Set 7 | ponta delgada
# Processing record 322 of Set 7 | san juan de uraba
# Processing record 323 of Set 7 | yakovlevka
# Processing record 324 of Set 7 | zalari
# Processing record 325 of Set 7 | zharkovskiy
# Processing record 326 of Set 7 | tasiilaq
# Processing record 327 of Set 7 | yulara
# Processing record 328 of Set 7 | nhulunbuy
# Processing record 329 of Set 7 | kamina
# Processing record 330 of Set 7 | anadyr
# Processing record 331 of Set 7 | katha
# City not found. Skipping...
# Processing record 332 of Set 7 | solnechnyy
# Processing record 333 of Set 7 | dingle
# Processing record 334 of Set 7 | vostok
# Processing record 335 of Set 7 | ngunguru
# Processing record 336 of Set 7 | port-cartier
# Processing record 337 of Set 7 | katherine
# Processing record 338 of Set 7 | isangel
# Processing record 339 of Set 7 | otacilio costa
# Processing record 340 of Set 7 | xining
# Processing record 341 of Set 7 | quatre cocos
# Processing record 342 of Set 7 | colares
# Processing record 343 of Set 7 | narsaq
# Processing record 344 of Set 7 | maraial
# Processing record 345 of Set 7 | mokrousovo
# Processing record 346 of Set 7 | yerbogachen
# Processing record 347 of Set 7 | tuktoyaktuk
# Processing record 348 of Set 7 | linhares
# Processing record 349 of Set 7 | taoudenni
# Processing record 350 of Set 7 | benguela
# Processing record 351 of Set 8 | khrebtovaya
# Processing record 352 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing record 353 of Set 8 | boshnyakovo
# Processing record 354 of Set 8 | qasigiannguit
# Processing record 355 of Set 8 | helena
# Processing record 356 of Set 8 | pisco
# Processing record 357 of Set 8 | koumac
# Processing record 358 of Set 8 | umea
# Processing record 359 of Set 8 | goya
# Processing record 360 of Set 8 | kendari
# Processing record 361 of Set 8 | nanortalik
# Processing record 362 of Set 8 | pong
# Processing record 363 of Set 8 | gazli
# Processing record 364 of Set 8 | curup
# Processing record 365 of Set 8 | nishihara
# Processing record 366 of Set 8 | yueyang
# Processing record 367 of Set 8 | baykit
# Processing record 368 of Set 8 | progreso
# Processing record 369 of Set 8 | belaya gora
# Processing record 370 of Set 8 | kholm
# Processing record 371 of Set 8 | kropotkin
# Processing record 372 of Set 8 | moussoro
# Processing record 373 of Set 8 | anda
# Processing record 374 of Set 8 | pacific grove
# Processing record 375 of Set 8 | qaqortoq
# Processing record 376 of Set 8 | chipata
# Processing record 377 of Set 8 | kikwit
# Processing record 378 of Set 8 | bandarbeyla
# Processing record 379 of Set 8 | panjwin
# City not found. Skipping...
# Processing record 380 of Set 8 | yanan
# City not found. Skipping...
# Processing record 381 of Set 8 | san luis
# Processing record 382 of Set 8 | mortka
# Processing record 383 of Set 8 | cabo san lucas
# Processing record 384 of Set 8 | maloy
# Processing record 385 of Set 8 | broken hill
# Processing record 386 of Set 8 | burica
# City not found. Skipping...
# Processing record 387 of Set 8 | jalu
# Processing record 388 of Set 8 | vila franca do campo
# Processing record 389 of Set 8 | walvis bay
# Processing record 390 of Set 8 | viransehir
# Processing record 391 of Set 8 | askarovo
# Processing record 392 of Set 8 | homer
# Processing record 393 of Set 8 | rio gallegos
# Processing record 394 of Set 8 | petropavlovsk-kamchatskiy
# Processing record 395 of Set 8 | cepu
# Processing record 396 of Set 8 | kadykchan
# City not found. Skipping...
# Processing record 397 of Set 8 | poum
# Processing record 398 of Set 8 | murray bridge
# Processing record 399 of Set 8 | ganzhou
# Processing record 400 of Set 8 | gejiu
# Processing record 401 of Set 9 | durban
# Processing record 402 of Set 9 | dharchula
# Processing record 403 of Set 9 | awjilah
# Processing record 404 of Set 9 | batagay-alyta
# Processing record 405 of Set 9 | reefton
# City not found. Skipping...
# Processing record 406 of Set 9 | port hardy
# Processing record 407 of Set 9 | bur gabo
# City not found. Skipping...
# Processing record 408 of Set 9 | gurlan
# Processing record 409 of Set 9 | klaksvik
# Processing record 410 of Set 9 | lebu
# Processing record 411 of Set 9 | kieta
# Processing record 412 of Set 9 | dawson creek
# Processing record 413 of Set 9 | chawinda
# Processing record 414 of Set 9 | ulladulla
# Processing record 415 of Set 9 | fort saint john
# City not found. Skipping...
# Processing record 416 of Set 9 | launceston
# Processing record 417 of Set 9 | cuamba
# Processing record 418 of Set 9 | constitucion
# Processing record 419 of Set 9 | lata
# Processing record 420 of Set 9 | sataua
# City not found. Skipping...
# Processing record 421 of Set 9 | raton
# Processing record 422 of Set 9 | mayumba
# Processing record 423 of Set 9 | esna
# Processing record 424 of Set 9 | isla mujeres
# Processing record 425 of Set 9 | vila do maio
# Processing record 426 of Set 9 | cap malheureux
# Processing record 427 of Set 9 | muncar
# Processing record 428 of Set 9 | saquena
# Processing record 429 of Set 9 | neiafu
# Processing record 430 of Set 9 | tiznit
# Processing record 431 of Set 9 | iquique
# Processing record 432 of Set 9 | comodoro rivadavia
# Processing record 433 of Set 9 | esso
# Processing record 434 of Set 9 | inhambane
# Processing record 435 of Set 9 | khristoforovo
# City not found. Skipping...
# Processing record 436 of Set 9 | tessalit
# Processing record 437 of Set 9 | hofn
# Processing record 438 of Set 9 | padang
# Processing record 439 of Set 9 | oshakati
# Processing record 440 of Set 9 | amur
# Processing record 441 of Set 9 | wakkanai
# Processing record 442 of Set 9 | talnakh
# Processing record 443 of Set 9 | odweyne
# Processing record 444 of Set 9 | tornio
# Processing record 445 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing record 446 of Set 9 | west bay
# Processing record 447 of Set 9 | bargal
# City not found. Skipping...
# Processing record 448 of Set 9 | north bend
# Processing record 449 of Set 9 | chuy
# Processing record 450 of Set 9 | abu kamal
# Processing record 451 of Set 10 | turayf
# Processing record 452 of Set 10 | sorland
# Processing record 453 of Set 10 | qabis
# City not found. Skipping...
# Processing record 454 of Set 10 | sorvag
# City not found. Skipping...
# Processing record 455 of Set 10 | san javier
# Processing record 456 of Set 10 | pittsburg
# Processing record 457 of Set 10 | miajadas
# Processing record 458 of Set 10 | anito
# Processing record 459 of Set 10 | kaniama
# Processing record 460 of Set 10 | gornyak
# Processing record 461 of Set 10 | mayo
# Processing record 462 of Set 10 | komsomolskiy
# Processing record 463 of Set 10 | mananara
# Processing record 464 of Set 10 | henderson
# Processing record 465 of Set 10 | deputatskiy
# Processing record 466 of Set 10 | tukrah
# Processing record 467 of Set 10 | sabinas hidalgo
# Processing record 468 of Set 10 | bogatyye saby
# Processing record 469 of Set 10 | kimbe
# Processing record 470 of Set 10 | maningrida
# Processing record 471 of Set 10 | college
# Processing record 472 of Set 10 | san rafael
# Processing record 473 of Set 10 | sola
# Processing record 474 of Set 10 | port lincoln
# Processing record 475 of Set 10 | kontagora
# Processing record 476 of Set 10 | guamal
# Processing record 477 of Set 10 | ulfborg
# Processing record 478 of Set 10 | tambovka
# Processing record 479 of Set 10 | sept-iles
# Processing record 480 of Set 10 | susaki
# Processing record 481 of Set 10 | hay river
# Processing record 482 of Set 10 | nanakuli
# Processing record 483 of Set 10 | san felipe
# Processing record 484 of Set 10 | floro
# Processing record 485 of Set 10 | plettenberg bay
# Processing record 486 of Set 10 | chara
# Processing record 487 of Set 10 | abong mbang
# Processing record 488 of Set 10 | rawson
# Processing record 489 of Set 10 | waddan
# Processing record 490 of Set 10 | grand-lahou
# Processing record 491 of Set 10 | salamiyah
# Processing record 492 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing record 493 of Set 10 | kutum
# Processing record 494 of Set 10 | helong
# Processing record 495 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing record 496 of Set 10 | touros
# Processing record 497 of Set 10 | yar-sale
# Processing record 498 of Set 10 | leningradskiy
# Processing record 499 of Set 10 | tolaga bay
# Processing record 500 of Set 10 | belmonte
# Processing record 501 of Set 11 | tuysarkan
# City not found. Skipping...
# Processing record 502 of Set 11 | carballo
# Processing record 503 of Set 11 | mezen
# Processing record 504 of Set 11 | mahibadhoo
# Processing record 505 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing record 506 of Set 11 | sinnamary
# Processing record 507 of Set 11 | gumdag
# Processing record 508 of Set 11 | san policarpo
# Processing record 509 of Set 11 | cocorit
# Processing record 510 of Set 11 | marienburg
# Processing record 511 of Set 11 | olga
# Processing record 512 of Set 11 | imbituba
# Processing record 513 of Set 11 | pine bluff
# Processing record 514 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing record 515 of Set 11 | samarai
# Processing record 516 of Set 11 | buluang
# Processing record 517 of Set 11 | manzil kamil
# Processing record 518 of Set 11 | saleaula
# City not found. Skipping...
# Processing record 519 of Set 11 | nushki
# Processing record 520 of Set 11 | halifax
# Processing record 521 of Set 11 | khasan
# Processing record 522 of Set 11 | ayr
# Processing record 523 of Set 11 | gamba
# Processing record 524 of Set 11 | saint-augustin
# Processing record 525 of Set 11 | getulio vargas
# Processing record 526 of Set 11 | longyearbyen
# Processing record 527 of Set 11 | kabwe
# Processing record 528 of Set 11 | boguchany
# Processing record 529 of Set 11 | sayat
# Processing record 530 of Set 11 | ossora
# Processing record 531 of Set 11 | leh
# Processing record 532 of Set 11 | vaitape
# Processing record 533 of Set 11 | yabrud
# Processing record 534 of Set 11 | zhezkazgan
# Processing record 535 of Set 11 | sitka
# Processing record 536 of Set 11 | hihifo
# City not found. Skipping...
# Processing record 537 of Set 11 | grootfontein
# Processing record 538 of Set 11 | lorengau
# Processing record 539 of Set 11 | pauleni-ciuc
# Processing record 540 of Set 11 | alyangula
# Processing record 541 of Set 11 | hastings
# Processing record 542 of Set 11 | emba
# Processing record 543 of Set 11 | maragheh
# Processing record 544 of Set 11 | soe
# Processing record 545 of Set 11 | nieves
# Processing record 546 of Set 11 | gerzat
# Processing record 547 of Set 11 | akureyri
# Processing record 548 of Set 11 | daru
# Processing record 549 of Set 11 | vao
# Processing record 550 of Set 11 | kysyl-syr
# Processing record 551 of Set 12 | hudson bay
# Processing record 552 of Set 12 | louisbourg
# City not found. Skipping...
# Processing record 553 of Set 12 | antalaha
# Processing record 554 of Set 12 | pontianak
# Processing record 555 of Set 12 | izumo
# Processing record 556 of Set 12 | oriximina
# Processing record 557 of Set 12 | farafangana
# Processing record 558 of Set 12 | soure
# Processing record 559 of Set 12 | castelbuono
# Processing record 560 of Set 12 | leshukonskoye
# Processing record 561 of Set 12 | canapi
# Processing record 562 of Set 12 | oskemen
# Processing record 563 of Set 12 | nemuro
# Processing record 564 of Set 12 | mecca
# Processing record 565 of Set 12 | nicoya
# Processing record 566 of Set 12 | ascension
# Processing record 567 of Set 12 | san vicente
# Processing record 568 of Set 12 | capreol
# Processing record 569 of Set 12 | kalmunai
# Processing record 570 of Set 12 | kedrovyy
# Processing record 571 of Set 12 | warrnambool
# Processing record 572 of Set 12 | tateyama
# Processing record 573 of Set 12 | caravelas
# Processing record 574 of Set 12 | rio grande
# Processing record 575 of Set 12 | toyooka
# Processing record 576 of Set 12 | nyurba
# Processing record 577 of Set 12 | luderitz
# Processing record 578 of Set 12 | tigil
# Processing record 579 of Set 12 | ialibu
# Processing record 580 of Set 12 | bowen
# Processing record 581 of Set 12 | inuvik
# Processing record 582 of Set 12 | sistranda
# Processing record 583 of Set 12 | tazovskiy
# Processing record 584 of Set 12 | udarnyy
# Processing record 585 of Set 12 | tilichiki
# Processing record 586 of Set 12 | baculin
# Processing record 587 of Set 12 | tammisaari
# Processing record 588 of Set 12 | aksu
# Processing record 589 of Set 12 | andenes
# Processing record 590 of Set 12 | sakakah
# Processing record 591 of Set 12 | santa cruz del sur
# Processing record 592 of Set 12 | cayenne
# Processing record 593 of Set 12 | bichena
# Processing record 594 of Set 12 | strezhevoy
# Processing record 595 of Set 12 | tabou
# Processing record 596 of Set 12 | kupang
# Processing record 597 of Set 12 | contamana
# Processing record 598 of Set 12 | zaysan
# Processing record 599 of Set 12 | kerewan
# Processing record 600 of Set 12 | dongargaon
# Processing record 601 of Set 13 | rawannawi
# City not found. Skipping...
# Processing record 602 of Set 13 | galesong
# Processing record 603 of Set 13 | corn island
# Processing record 604 of Set 13 | hambantota
# Processing record 605 of Set 13 | richards bay
# Processing record 606 of Set 13 | bolsheustikinskoye
# City not found. Skipping...
# Processing record 607 of Set 13 | tura
# Processing record 608 of Set 13 | zachagansk
# City not found. Skipping...
# Processing record 609 of Set 13 | ous
# Processing record 610 of Set 13 | beipiao
# Processing record 611 of Set 13 | zhigansk
# Processing record 612 of Set 13 | djibo
# Processing record 613 of Set 13 | lazaro cardenas
# Processing record 614 of Set 13 | romanovo
# Processing record 615 of Set 13 | waw
# Processing record 616 of Set 13 | christchurch
# Processing record 617 of Set 13 | seredeyskiy
# Processing record 618 of Set 13 | ileza
# Processing record 619 of Set 13 | albemarle
# Processing record 620 of Set 13 | gardez
# Processing record 621 of Set 13 | merauke
# Processing record 622 of Set 13 | razdolinsk
# Processing record 623 of Set 13 | sabha
# Processing record 624 of Set 13 | conceicao da barra
# Processing record 625 of Set 13 | whitehorse
# Processing record 626 of Set 13 | nortelandia
# Processing record 627 of Set 13 | larsnes
# Processing record 628 of Set 13 | waterloo
# Processing record 629 of Set 13 | bubaque
# Processing record 630 of Set 13 | sambava
# Processing record 631 of Set 13 | upata
# Processing record 632 of Set 13 | noumea
# Processing record 633 of Set 13 | hohhot
# Processing record 634 of Set 13 | airai
# Processing record 635 of Set 13 | magadan
# Processing record 636 of Set 13 | west wendover
# Processing record 637 of Set 13 | mogadishu
# Processing record 638 of Set 13 | klaebu
# Processing record 639 of Set 13 | babanusah
# City not found. Skipping...
# Processing record 640 of Set 13 | santa cruz
# Processing record 641 of Set 13 | namtsy
# Processing record 642 of Set 13 | gisborne
# Processing record 643 of Set 13 | bambanglipuro
# Processing record 644 of Set 13 | cabo rojo
# Processing record 645 of Set 13 | denpasar
# Processing record 646 of Set 13 | marawi
# Processing record 647 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing record 648 of Set 13 | ambovombe
# Processing record 649 of Set 13 | sao filipe
# Processing record 650 of Set 13 | manadhoo
# Processing record 651 of Set 14 | cascais
# Processing record 652 of Set 14 | wanning
# Processing record 653 of Set 14 | micheweni
# Processing record 654 of Set 14 | czestochowa
# Processing record 655 of Set 14 | lianran
# Processing record 656 of Set 14 | tombouctou
# Processing record 657 of Set 14 | kotma
# Processing record 658 of Set 14 | senno
# Processing record 659 of Set 14 | clyde
# Processing record 660 of Set 14 | oktyabrskiy
# Processing record 661 of Set 14 | payakumbuh
# Processing record 662 of Set 14 | huilong
# Processing record 663 of Set 14 | chapais
# Processing record 664 of Set 14 | ballina
# Processing record 665 of Set 14 | grindavik
# Processing record 666 of Set 14 | vallenar
# Processing record 667 of Set 14 | turan
# Processing record 668 of Set 14 | kamenka
# Processing record 669 of Set 14 | gasa
# Processing record 670 of Set 14 | haverfordwest
# Processing record 671 of Set 14 | bairiki
# Processing record 672 of Set 14 | ranong
# Processing record 673 of Set 14 | dunaharaszti
# Processing record 674 of Set 14 | horodyshche
# Processing record 675 of Set 14 | magdagachi
# Processing record 676 of Set 14 | oussouye
# Processing record 677 of Set 14 | rorvik
# Processing record 678 of Set 14 | mitikas
# Processing record 679 of Set 14 | stornoway
# Processing record 680 of Set 14 | dunedin
# Processing record 681 of Set 14 | kloulklubed
# Processing record 682 of Set 14 | bac lieu
# Processing record 683 of Set 14 | yangjiang
# Processing record 684 of Set 14 | axim
# Processing record 685 of Set 14 | karachi
# Processing record 686 of Set 14 | igboho
# Processing record 687 of Set 14 | shache
# Processing record 688 of Set 14 | tezu
# Processing record 689 of Set 14 | sredec
# City not found. Skipping...
# Processing record 690 of Set 14 | secovce
# Processing record 691 of Set 14 | diapaga
# Processing record 692 of Set 14 | shimizu
# Processing record 693 of Set 14 | dayong
# Processing record 694 of Set 14 | vilyuysk
# Processing record 695 of Set 14 | luanda
# Processing record 696 of Set 14 | isla aguada
# Processing record 697 of Set 14 | port blair
# Processing record 698 of Set 14 | paamiut
# Processing record 699 of Set 14 | nazira
# Processing record 700 of Set 14 | poplaca
# Processing record 701 of Set 15 | thinadhoo
# Processing record 702 of Set 15 | zonguldak
# Processing record 703 of Set 15 | xadani
# City not found. Skipping...
# Processing record 704 of Set 15 | severnyy
# Processing record 705 of Set 15 | chumikan
# Processing record 706 of Set 15 | sibu
# Processing record 707 of Set 15 | mufumbwe
# Processing record 708 of Set 15 | konza
# Processing record 709 of Set 15 | pouembout
# Processing record 710 of Set 15 | sibolga
# Processing record 711 of Set 15 | asyut
# Processing record 712 of Set 15 | ust-uda
# Processing record 713 of Set 15 | takapau
# Processing record 714 of Set 15 | sumbe
# Processing record 715 of Set 15 | pundaguitan
# Processing record 716 of Set 15 | honavar
# Processing record 717 of Set 15 | santa maria
# Processing record 718 of Set 15 | kokopo
# Processing record 719 of Set 15 | marsaxlokk
# Processing record 720 of Set 15 | barguzin
# Processing record 721 of Set 15 | ornskoldsvik
# Processing record 722 of Set 15 | byron bay
# Processing record 723 of Set 15 | waipawa
# Processing record 724 of Set 15 | bam
# Processing record 725 of Set 15 | mazamari
# Processing record 726 of Set 15 | seoul
# Processing record 727 of Set 15 | trairi
# Processing record 728 of Set 15 | poya
# Processing record 729 of Set 15 | araxa
# Processing record 730 of Set 15 | sfantu gheorghe
# Processing record 731 of Set 15 | kabalo
# Processing record 732 of Set 15 | cochabamba
# Processing record 733 of Set 15 | ibra
# Processing record 734 of Set 15 | natal
# Processing record 735 of Set 15 | san juan
# Processing record 736 of Set 15 | gillette
# Processing record 737 of Set 15 | iguai
# Processing record 738 of Set 15 | dutse
# Processing record 739 of Set 15 | sedalia
# Processing record 740 of Set 15 | alofi
# Processing record 741 of Set 15 | mackay
# Processing record 742 of Set 15 | kjopsvik
# Processing record 743 of Set 15 | araceli
# Processing record 744 of Set 15 | inza
# Processing record 745 of Set 15 | oyama
# Processing record 746 of Set 15 | domoni
# Processing record 747 of Set 15 | marcona
# City not found. Skipping...
# Processing record 748 of Set 15 | taltal
# Processing record 749 of Set 15 | labytnangi
# Processing record 750 of Set 15 | greenwood
# Processing record 751 of Set 16 | san jose
# Processing record 752 of Set 16 | los llanos de aridane
# Processing record 753 of Set 16 | urengoy
# Processing record 754 of Set 16 | neryungri
# Processing record 755 of Set 16 | ouadda
# Processing record 756 of Set 16 | ginda
# Processing record 757 of Set 16 | adre
# Processing record 758 of Set 16 | mutoko
# Processing record 759 of Set 16 | bangar
# Processing record 760 of Set 16 | skagastrond
# City not found. Skipping...
# Processing record 761 of Set 16 | tiarei
# Processing record 762 of Set 16 | gravdal
# Processing record 763 of Set 16 | hirara
# Processing record 764 of Set 16 | sabya
# Processing record 765 of Set 16 | kashi
# Processing record 766 of Set 16 | tenenkou
# Processing record 767 of Set 16 | riyadh
# Processing record 768 of Set 16 | sindor
# Processing record 769 of Set 16 | olawa
# Processing record 770 of Set 16 | ketchikan
# Processing record 771 of Set 16 | that phanom
# Processing record 772 of Set 16 | broome
# Processing record 773 of Set 16 | moerai
# Processing record 774 of Set 16 | guaratinga
# Processing record 775 of Set 16 | svetlyy
# Processing record 776 of Set 16 | valparaiso
# Processing record 777 of Set 16 | goderich
# Processing record 778 of Set 16 | dali
# Processing record 779 of Set 16 | namibe
# --------------------------
# Data Retrieval Complete

# %%
# Check the count of cities appended to city_data
len(city_data)
# Out:
# 717

# %%
# Convert list to DF and check the head
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness   Wind  \
# 0         Dikson  73.51   80.55     40.69        88          12  12.48
# 1  Mount Gambier -37.83  140.77     44.60        93          40   8.05
# 2        Iralaya  15.00  -83.23     84.20        79          40   1.88
# 3           Hilo  19.73 -155.09     73.40        64          90   4.70
# 4   Punta Arenas -53.15  -70.92     39.20        85         100   5.82
#
#   Weather Description Country                 Date
# 0          few clouds      RU  2020-09-03 15:03:58
# 1    scattered clouds      AU  2020-09-03 15:03:58
# 2    scattered clouds      HN  2020-09-03 15:03:58
# 3     overcast clouds      US  2020-09-03 15:00:06
# 4     overcast clouds      CL  2020-09-03 14:52:52

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", 
                    "Humidity", "Cloudiness", "Wind", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dikson      RU  73.51   80.55     40.69        88          12
# 1  Mount Gambier      AU -37.83  140.77     44.60        93          40
# 2        Iralaya      HN  15.00  -83.23     84.20        79          40
# 3           Hilo      US  19.73 -155.09     73.40        64          90
# 4   Punta Arenas      CL -53.15  -70.92     39.20        85         100
#
#     Wind Weather Description
# 0  12.48          few clouds
# 1   8.05    scattered clouds
# 2   1.88    scattered clouds
# 3   4.70     overcast clouds
# 4   5.82     overcast clouds

# %%
# Create variable to save the file
output_file = ("Weather_Database/WeatherPy_Database.csv")
# Save DF as a csv file 
city_data_df.to_csv(output_file, index_label="City_ID")
